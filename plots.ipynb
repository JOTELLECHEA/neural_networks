# %%
# Written By : Jonathan O. Tellechea
# Adviser    : Mike Hance, Phd
# Research   : Using a neural network to maximize the significance of tttHH production.
# Description: Plotting data 
# Reference  : http://cdsweb.cern.ch/record/2220969/files/ATL-PHYS-PUB-2016-023.pdf
import numpy as np
import pandas as pd
import uproot
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline  

tree = 'OutputTree'
branches = ['numjet','numlep','btag','srap','cent','m_bb','h_b','mt1','mt2','mt3','dr1','dr2','dr3']
numofbranches = len(branches)

signal         = uproot.open('new_signal_tthh.root')[tree]
df_signal      = signal.pandas.df(branches)
background     = uproot.open('background.root')[tree]
df_background  = background.pandas.df(branches)
alldata        = uproot.open('full.root')[tree]
df_alldata     = alldata.pandas.df(branches)

X = df_alldata
y = np.concatenate((np.ones(df_signal.shape[0]), np.zeros(df_background.shape[0])))
X_dev,X_eval, y_dev,y_eval = train_test_split(X, y, test_size = 0.1, random_state=42)
X_train,X_test, y_train,y_test = train_test_split(X_dev, y_dev, test_size = 0.5,random_state=42)

# %%
numjet_sig = df_signal[['numjet']].values
numjet_all = df_alldata[['numjet']].values
numlep_sig = df_signal[['numlep']].values
numlep_all = df_alldata[['numlep']].values
btag_sig = df_signal[['btag']].values
btag_all = df_alldata[['btag']].values
srap_sig = df_signal[['srap']].values
srap_all = df_alldata[['srap']].values
cent_sig = df_signal[['cent']].values
cent_all = df_alldata[['cent']].values
m_bb_sig = df_signal[['m_bb']].values
m_bb_all = df_alldata[['m_bb']].values
h_b_sig = df_signal[['h_b']].values
h_b_all = df_alldata[['h_b']].values
mt1_sig = df_signal[['mt1']].values
mt1_all = df_alldata[['mt1']].values
mt2_sig = df_signal[['mt2']].values
mt2_all = df_alldata[['mt2']].values
mt3_sig = df_signal[['mt3']].values
mt3_all = df_alldata[['mt3']].values
dr1_sig = df_signal[['dr1']].values
dr1_all = df_alldata[['dr1']].values
dr2_sig = df_signal[['dr2']].values
dr2_all = df_alldata[['dr2']].values
dr3_sig = df_signal[['dr3']].values
dr3_all = df_alldata[['dr3']].values

# %%
fig1 = plt.figure(figsize=(15,10))
fig1.add_subplot(221)
bins = np.linspace(1,3,3)
plt.hist(numlep_all,bins=bins,label='all')
plt.hist(numlep_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('numlep')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig1.add_subplot(222)
bins = np.linspace(1, 11, 10)
plt.hist(numjet_all,bins=bins,label='all')
plt.hist(numjet_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('numjet')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig1.add_subplot(223)
bins = np.linspace(1, 10, 10)
plt.hist(btag_all,bins=bins,label='all')
plt.hist(btag_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('btag')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig1.add_subplot(224)
bins = np.linspace(1, 10, 100)
plt.hist(srap_all,bins=bins,label='all')
plt.hist(srap_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('srap')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
plt.show()
# plt.savefig('sig.png')
###################################################

# %%
fig2 = plt.figure(figsize=(15,10))
fig2.add_subplot(221)
bins = np.linspace(1,1500,1500)
plt.hist(m_bb_all,bins=bins,label='all')
plt.hist(m_bb_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('m_bb')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig2.add_subplot(222)
bins = np.linspace(1, 250, 250)
plt.hist(h_b_all,bins=bins,label='all')
plt.hist(h_b_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('h_b')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig2.add_subplot(223)
bins = np.linspace(1, 300, 300)
plt.hist(mt1_all,bins=bins,label='all')
plt.hist(mt1_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('mt1')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig2.add_subplot(224)
bins = np.linspace(1, 300, 300)
plt.hist(mt2_all,bins=bins,label='all')
plt.hist(mt2_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('mt2')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
plt.show()
# plt.savefig('sig.png')
###################################################

# %%
fig4 = plt.figure(figsize=(15,10))
fig4.add_subplot(221)
bins = np.linspace(1,200,200)
plt.hist(mt3_all,bins=bins,label='all')
plt.hist(mt3_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('mt3')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig4.add_subplot(222)
bins = np.linspace(1, 11, 10)
plt.hist(dr1_all,bins=bins,label='all')
plt.hist(dr1_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('dr1')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig4.add_subplot(223)
bins = np.linspace(1, 10, 10)
plt.hist(dr2_all,bins=bins,label='all')
plt.hist(dr2_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('dr2')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig4.add_subplot(224)
bins = np.linspace(1, 10, 10)
plt.hist(dr3_all,bins=bins,label='all')
plt.hist(dr3_sig,bins=bins,label='sig')
plt.yscale('log')
plt.legend()
plt.xlabel('dr3')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
plt.show()
# plt.savefig('sig.png')
###################################################

# %%
numjet_sig = X_train[['numjet']].values
numlep_sig = X_train[['numlep']].values
btag_sig = X_train[['btag']].values
srap_sig = X_train[['srap']].values
cent_sig = X_train[['cent']].values
m_bb_sig = X_train[['m_bb']].values
h_b_sig = X_train[['h_b']].values
mt1_sig = X_train[['mt1']].values
mt2_sig = X_train[['mt2']].values
mt3_sig = X_train[['mt3']].values
dr1_sig = X_train[['dr1']].values
dr2_sig = X_train[['dr2']].values
dr3_sig = X_train[['dr3']].values

# %%
fig5 = plt.figure(figsize=(15,10))
fig5.add_subplot(221)
bins = np.linspace(1,3,3)
plt.hist(numlep_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('numlep')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig5.add_subplot(222)
bins = np.linspace(1, 11, 10)
plt.hist(numjet_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('numjet')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig5.add_subplot(223)
bins = np.linspace(1, 10, 10)
plt.hist(btag_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('btag')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig5.add_subplot(224)
bins = np.linspace(1, 10, 100)
plt.hist(srap_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('srap')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
plt.show()
# plt.savefig('sig.png')
###################################################

# %%
fig6 = plt.figure(figsize=(15,10))
fig6.add_subplot(221)
bins = np.linspace(1,1500,1500)
plt.hist(m_bb_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('m_bb')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig6.add_subplot(222)
bins = np.linspace(1, 250, 250)
plt.hist(h_b_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('h_b')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig6.add_subplot(223)
bins = np.linspace(1, 300, 300)
plt.hist(mt1_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('mt1')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig6.add_subplot(224)
bins = np.linspace(1, 300, 300)
plt.hist(mt2_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('mt2')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
plt.show()
# plt.savefig('sig.png')
###################################################

# %%
fig7 = plt.figure(figsize=(15,10))
fig7.add_subplot(221)
bins = np.linspace(1,200,200)
plt.hist(mt3_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('mt3')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig7.add_subplot(222)
bins = np.linspace(1, 10, 10)
plt.hist(dr1_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('dr1')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig7.add_subplot(223)
bins = np.linspace(1, 10, 10)
plt.hist(dr2_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('dr2')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
# plt.show()
# plt.savefig('sig.png')
###################################################
fig7.add_subplot(224)
bins = np.linspace(1, 10, 10)
plt.hist(dr3_sig,bins=bins,label='all')
plt.yscale('log')
plt.legend()
plt.xlabel('dr3')
plt.ylabel('Events Not Normalised / LOG')
plt.title('pre split')
plt.show()
# plt.savefig('sig.png')
###################################################

# %%
X.head(10)
# Out:
#        numjet  numlep  btag        srap      cent        m_bb         h_b  \
# entry
# 0         8.0     1.0   4.0    2.186833  0.367174  433.809540  479.091492
# 1         6.0     1.0   5.0    0.576886  0.509182   87.644836  626.812500
# 2         7.0     1.0   2.0    0.183263  0.567582   38.105064  151.618423
# 3         5.0     1.0   4.0    1.078668  0.812813  118.239693  564.737366
# 4         5.0     1.0   1.0 -999.000000  0.602797    0.000000   79.910789
# 5         7.0     1.0   3.0    0.537749  0.493625  117.263420  440.782440
# 6         6.0     1.0   4.0    0.670285  0.459809  118.746956  279.042572
# 7         9.0     1.0   3.0    1.849032  0.245280  226.512054  190.737427
# 8         5.0     1.0   4.0    0.919542  0.765449  109.912018  297.274384
# 9         8.0     1.0   4.0    0.873054  0.435864  177.088348  454.109009
#
#               mt1    mt2  mt3       dr1    dr2  dr3
# entry
# 0      198.145355 -999.0  0.0  0.002296 -999.0  0.0
# ...
